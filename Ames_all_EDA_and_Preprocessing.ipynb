# %%
import numpy as np
import pandas as pd
import math
import scipy  #Rob:added scipy for the stats module
from sklearn.impute import KNNImputer #Rob: added
from sklearn.preprocessing import StandardScaler #Rob:added

import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
#Rob: changed the filepath to better fit the directory structure
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

# %%
train.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
train.shape
# Out:
# (1460, 81)

# %%
train.describe().T
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# TotalBsmtSF    1460.0    1057.429452    438.705324      0.0     795.75
# 1stFlrSF       1460.0    1162.626712    386.587738    334.0     882.00
# 2ndFlrSF       1460.0     346.992466    436.528436      0.0       0.00
# LowQualFinSF   1460.0       5.844521     48.623081      0.0       0.00
# GrLivArea      1460.0    1515.463699    525.480383    334.0    1129.50
# BsmtFullBath   1460.0       0.425342      0.518911      0.0       0.00
# BsmtHalfBath   1460.0       0.057534      0.238753      0.0       0.00
# FullBath       1460.0       1.565068      0.550916      0.0       1.00
# HalfBath       1460.0       0.382877      0.502885      0.0       0.00
# BedroomAbvGr   1460.0       2.866438      0.815778      0.0       2.00
# KitchenAbvGr   1460.0       1.046575      0.220338      0.0       1.00
# TotRmsAbvGrd   1460.0       6.517808      1.625393      2.0       5.00
# Fireplaces     1460.0       0.613014      0.644666      0.0       0.00
# GarageYrBlt    1379.0    1978.506164     24.689725   1900.0    1961.00
# GarageCars     1460.0       1.767123      0.747315      0.0       1.00
# GarageArea     1460.0     472.980137    213.804841      0.0     334.50
# WoodDeckSF     1460.0      94.244521    125.338794      0.0       0.00
# OpenPorchSF    1460.0      46.660274     66.256028      0.0       0.00
# EnclosedPorch  1460.0      21.954110     61.119149      0.0       0.00
# 3SsnPorch      1460.0       3.409589     29.317331      0.0       0.00
# ScreenPorch    1460.0      15.060959     55.757415      0.0       0.00
# PoolArea       1460.0       2.758904     40.177307      0.0       0.00
# MiscVal        1460.0      43.489041    496.123024      0.0       0.00
# MoSold         1460.0       6.321918      2.703626      1.0       5.00
# YrSold         1460.0    2007.815753      1.328095   2006.0    2007.00
# SalePrice      1460.0  180921.195890  79442.502883  34900.0  129975.00
#
#                     50%        75%       max
# Id                730.5    1095.25    1460.0
# MSSubClass         50.0      70.00     190.0
# LotFrontage        69.0      80.00     313.0
# LotArea          9478.5   11601.50  215245.0
# OverallQual         6.0       7.00      10.0
# OverallCond         5.0       6.00       9.0
# YearBuilt        1973.0    2000.00    2010.0
# YearRemodAdd     1994.0    2004.00    2010.0
# MasVnrArea          0.0     166.00    1600.0
# BsmtFinSF1        383.5     712.25    5644.0
# BsmtFinSF2          0.0       0.00    1474.0
# BsmtUnfSF         477.5     808.00    2336.0
# TotalBsmtSF       991.5    1298.25    6110.0
# 1stFlrSF         1087.0    1391.25    4692.0
# 2ndFlrSF            0.0     728.00    2065.0
# LowQualFinSF        0.0       0.00     572.0
# GrLivArea        1464.0    1776.75    5642.0
# BsmtFullBath        0.0       1.00       3.0
# BsmtHalfBath        0.0       0.00       2.0
# FullBath            2.0       2.00       3.0
# HalfBath            0.0       1.00       2.0
# BedroomAbvGr        3.0       3.00       8.0
# KitchenAbvGr        1.0       1.00       3.0
# TotRmsAbvGrd        6.0       7.00      14.0
# Fireplaces          1.0       1.00       3.0
# GarageYrBlt      1980.0    2002.00    2010.0
# GarageCars          2.0       2.00       4.0
# GarageArea        480.0     576.00    1418.0
# WoodDeckSF          0.0     168.00     857.0
# OpenPorchSF        25.0      68.00     547.0
# EnclosedPorch       0.0       0.00     552.0
# 3SsnPorch           0.0       0.00     508.0
# ScreenPorch         0.0       0.00     480.0
# PoolArea            0.0       0.00     738.0
# MiscVal             0.0       0.00   15500.0
# MoSold              6.0       8.00      12.0
# YrSold           2008.0    2009.00    2010.0
# SalePrice      163000.0  214000.00  755000.0

# %% [markdown]
# ### Divide by data type

# %%
#Rob: changed to list(...columns)
cat_features = list(train.select_dtypes(include=['object']).columns)
print(f'Object types:  {len(cat_features)}')
print(cat_features)
# Out:
# Object types:  43
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %%
#Rob: changed to list(...columns)

num_features = list(train.select_dtypes(include=['int64','float64']).columns)
print(f'Numeric types:  {len(num_features)}')
print(num_features)
# Out:
# Numeric types:  38
# ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']

# %%
# Some numeric features are categorical by nature (TBD later on being potentially ordinal):
train['MSSubClass'] = train.MSSubClass.apply(lambda x: str(x))
train['MoSold'] = train.MoSold.apply(lambda x: str(x))
train['YrSold'] = train.YrSold.apply(lambda x: str(x))

# %%
cat_features += ['MSSubClass', 'MoSold', 'YrSold']
print(f'Object types:  {len(cat_features)}')
# Out:
# Object types:  46

# %%
# Also remove ID and SalePrice from the features
not_numeric = ['Id', 'SalePrice', 'MSSubClass', 'MoSold', 'YrSold']
num_features = [f for f in num_features if f not in not_numeric] 
print(f'Numeric types:  {len(num_features)}')
# Out:
# Numeric types:  33

# %%
print(cat_features)
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition', 'MSSubClass', 'MoSold', 'YrSold']

# %%
print(num_features)
# Out:
# ['LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal']

# %% [markdown]
# ### Classify Ordinal vs. Nominal

# %% [markdown]
# By default, all categorical features are nominal.  The following are classified ordinal:
# - levels are clearly ordered (e.g. Functional, LandSlope, LotShape). This is regardless of the feature's correlation with price, e.g. may be completely uncorrelated.
# - if we __suspect__ order, verify by a boxplot Price~Feature (e.g. 'MSSubClass'). Classify as ordinal only if there is visual correlation with sorted levels

# %%
cat_ordinal = [  # definitely ordinal
'Street',
'Alley',
'LotShape',
'Utilities',
'LandSlope',
'ExterQual',
'ExterCond',
'BsmtQual',
'BsmtCond',
'BsmtExposure',
'BsmtFinType1',
'BsmtFinType2',
'HeatingQC',
'CentralAir',
'KitchenQual',
'Functional',
'FireplaceQu',
'GarageFinish',
'GarageQual',
'GarageCond',
'PavedDrive',
'PoolQC',
]
print(f'Definitely ordinal:  {len(cat_ordinal)}')
# Out:
# Definitely ordinal:  22

# %%
cat_ordinal_candidates = [ # potentially ordinal
'MSSubClass',
'LandContour',
'LotConfig',
'BldgType',    
'HouseStyle',    
'Foundation',
'Electrical',
'Fence',
'SaleType',
'SaleCondition'    
]
print(f'Potentially ordinal:  {len(cat_ordinal_candidates)}')
# Out:
# Potentially ordinal:  10

# %%
cat_nominal = [f for f in cat_features if f not in cat_ordinal and f not in cat_ordinal_candidates] 
print(f'Nominal features:  {len(cat_nominal)}')
cat_nominal
# Out:
# Nominal features:  14
# ['MSZoning',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'Heating',
#  'GarageType',
#  'MiscFeature',
#  'MoSold',
#  'YrSold']

# %%
# We care about display order for the candidate ordinals:
#Rob: added VWD to SaleType, removed comma after SaleCondition 

display_order = {
'MSSubClass': ['20', '30', '40', '45', '50', '60', '70', '75', '80', '85', '90', '120', '160', '180', '190'],
'LandContour': ['Lvl','Bnk', 'HLS', 'Low'],
'LotConfig': ['Inside', 'FR2', 'Corner', 'CulDSac', 'FR3'],
'BldgType':    ['1Fam', '2fmCon', 'Duplex', 'TwnhsE', 'Twnhs'],
'HouseStyle':  ['1Story', '1.5Unf', '1.5Fin', '2Story', '2.5Unf', '2.5Fin', 'SFoyer', 'SLvl'],    
'Foundation': ['PConc', 'CBlock', 'BrkTil', 'Wood', 'Slab', 'Stone'],
'Electrical': ['SBrkr', 'FuseF', 'FuseA', 'FuseP', 'Mix'],
'Fence': ['GdPrv','MnPrv','GdWo', 'MnWw','NA'],
'SaleType': ['WD','CWD','VWD','New','COD','Con','ConLw','ConLI','ConLD','Oth'],
'SaleCondition': ['Normal','Abnorml','AdjLand','Alloca','Family','Partial']
}

# %%
#Rob: this piece of code didn't run properly for me as is, what's n? I changed to nc to get it to run. 
#Rob: assigned nc = 3 explicitly to get this to work
# # plt.subplots(nrows, ncols, figsize=(width, height))
nc =3
nr =  1+len(cat_ordinal_candidates)//nc

f,axes = plt.subplots(nr, nc, figsize=(nc*5, nr*5))

counter = 0
for f in cat_ordinal_candidates:
    sns.boxplot(f, 'SalePrice', data=train, order=display_order[f],ax = axes[counter//nc][counter%nc])
    counter+=1

# %% [markdown]
# Conclusion: there is no internal order that would cause a visible correlation with the Price. All candidate features should be classified as nominal.
# Rob:added for Sam - Fence looks more ordinal than not so adding to ordinals

# %%
##Rob: adding Fence as an ordinal categorical feature
cat_ordinal_candidates = [f for f in cat_ordinal_candidates if f not in ['Fence']]
cat_ordinal += ['Fence']
cat_nominal = cat_nominal + cat_ordinal_candidates
cat_nominal = list(set(cat_nominal))
cat_ordinal = list(set(cat_ordinal))

print(f'Nominal features:  {len(cat_nominal)}')
print(f'Ordinal features:  {len(cat_ordinal)}')
# Out:
# Nominal features:  23
# Ordinal features:  23

# %%
cat_nominal
# Out:
# ['LandContour',
#  'HouseStyle',
#  'Condition2',
#  'RoofStyle',
#  'Neighborhood',
#  'RoofMatl',
#  'MSSubClass',
#  'Exterior1st',
#  'MasVnrType',
#  'LotConfig',
#  'GarageType',
#  'Exterior2nd',
#  'BldgType',
#  'Foundation',
#  'YrSold',
#  'Heating',
#  'MiscFeature',
#  'SaleCondition',
#  'MSZoning',
#  'Condition1',
#  'MoSold',
#  'SaleType',
#  'Electrical']

# %% [markdown]
# ### Categorical features: Impute nan

# %% [markdown]
# Verify each categorical feature to apply the following approach:
# - nominal features: replace nan with string 'None' unless has specific meaning
# - ordinal features: replace nan with 0 unless nan means something else. Nan typically means the absence of the feature such as 'no garage'.  Later, map the remaining levels to 1,2,..

# %%
for f in cat_nominal:
    nans = train[f].isna().sum()
    if nans>0:
        print(f'{nans}   nans in   {f}')
# Out:
# 8   nans in   MasVnrType
# 81   nans in   GarageType
# 1406   nans in   MiscFeature
# 1   nans in   Electrical

# %%
for f in cat_ordinal:
    nans = train[f].isna().sum()
    if nans>0:
        print(f'{nans}   nans in   {f}')
# Out:
# 690   nans in   FireplaceQu
# 81   nans in   GarageQual
# 1453   nans in   PoolQC
# 1179   nans in   Fence
# 38   nans in   BsmtExposure
# 37   nans in   BsmtFinType1
# 81   nans in   GarageCond
# 1369   nans in   Alley
# 81   nans in   GarageFinish
# 38   nans in   BsmtFinType2
# 37   nans in   BsmtCond
# 37   nans in   BsmtQual

# %% [markdown]
# Checked all missing columns, the default approach of replacing with 'None' and 0 should work

# %%
for f in cat_nominal:
    train[f].fillna('None', inplace=True)

# %%
for f in cat_ordinal:
    train[f].fillna(0, inplace=True)

# %% [markdown]
# ### Map Ordinal to numeric

# %%
# NB map the FULL dictionary from the description b/c some labels may appear only in the test set
# still, check unique levels for all ordinals in the train set
#Rob: we can remove this per comments above

{f: list(train[f].unique()) for f in cat_ordinal}
# Out:
# {'FireplaceQu': [0, 'TA', 'Gd', 'Fa', 'Ex', 'Po'],
#  'GarageQual': ['TA', 'Fa', 'Gd', 0, 'Ex', 'Po'],
#  'LotShape': ['Reg', 'IR1', 'IR2', 'IR3'],
#  'PoolQC': [0, 'Ex', 'Fa', 'Gd'],
#  'Functional': ['Typ', 'Min1', 'Maj1', 'Min2', 'Mod', 'Maj2', 'Sev'],
#  'ExterCond': ['TA', 'Gd', 'Fa', 'Po', 'Ex'],
#  'HeatingQC': ['Ex', 'Gd', 'TA', 'Fa', 'Po'],
#  'LandSlope': ['Gtl', 'Mod', 'Sev'],
#  'Fence': [0, 'MnPrv', 'GdWo', 'GdPrv', 'MnWw'],
#  'BsmtExposure': ['No', 'Gd', 'Mn', 'Av', 0],
#  'BsmtFinType1': ['GLQ', 'ALQ', 'Unf', 'Rec', 'BLQ', 0, 'LwQ'],
#  'GarageCond': ['TA', 'Fa', 0, 'Gd', 'Po', 'Ex'],
#  'Utilities': ['AllPub', 'NoSeWa'],
#  'Alley': [0, 'Grvl', 'Pave'],
#  'GarageFinish': ['RFn', 'Unf', 'Fin', 0],
#  'KitchenQual': ['Gd', 'TA', 'Ex', 'Fa'],
#  'BsmtFinType2': ['Unf', 'BLQ', 0, 'ALQ', 'Rec', 'LwQ', 'GLQ'],
#  'CentralAir': ['Y', 'N'],
#  'BsmtCond': ['TA', 'Gd', 0, 'Fa', 'Po'],
#  'ExterQual': ['Gd', 'TA', 'Ex', 'Fa'],
#  'BsmtQual': ['Gd', 'TA', 'Ex', 0, 'Fa'],
#  'PavedDrive': ['Y', 'N', 'P'],
#  'Street': ['Pave', 'Grvl']}

# %%
# Mapping convention: higher levels ~ higher price (NOT always applicable, e.g. LotShape)
# arbitrary convention for the sake of interpretation consistency, should not affect any ML
ordinal_to_numeric = {
    'Street': {'Grvl':1, 'Pave':2},
    'Alley': {'Grvl':1, 'Pave':2},
    'LotShape': {'Reg':1, 'IR1':2, 'IR2':3, 'IR3':4},
    'Utilities': {'ELO':1, 'NoSeWa':2, 'NoSewr':3, 'AllPub':4},
    'LandSlope': {'Gtl':1, 'Mod':2, 'Sev':3}, #Rob: order reversed? shouldn't affect anything but the interpretation
    'Fence':{'MnWw':1, 'GdWo':2, 'MnPrv':3, 'GdPrv':4}, #Rob added per Sam's analysis
    'ExterQual': {'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5},
    'ExterCond': {'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5},

    'BsmtQual': {'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5},
    'BsmtCond': {'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5},
    'BsmtExposure': {'No':1, 'Mn':2, 'Av':3, 'Gd':4},
    'BsmtFinType1': {'Unf':1, 'LwQ':2, 'Rec':3, 'BLQ':4, 'ALQ':5, 'GLQ':6},
    'BsmtFinType2': {'Unf':1, 'LwQ':2, 'Rec':3, 'BLQ':4, 'ALQ':5, 'GLQ':6},

    'HeatingQC': {'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5},
    'CentralAir': {'N':0, 'Y':1},
    'KitchenQual': {'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5},
    # bigger step for 'Typical' - Rob: why use a larger step between Min1 and Typ?
    'Functional': {'Sal':1, 'Sev':2, 'Maj2':3, 'Maj1':4, 'Mod':5, 'Min2':6, 'Min1':7, 'Typ':10},  
    'FireplaceQu': {'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5},

    'GarageFinish': {'Unf':1, 'RFn':2, 'Fin':3},
    'GarageQual': {'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5},
    'GarageCond': {'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5},

    'PavedDrive': {'N':1, 'P':2, 'Y':3},
    'PoolQC': {'Fa':2, 'TA':3, 'Gd':4, 'Ex':5},
}

# %%
for f in ordinal_to_numeric:
    train[f].replace(ordinal_to_numeric[f], inplace=True)

# %%
# verify 
train.head(10)
# Out:
#    Id MSSubClass MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0   1         60       RL         65.0     8450       2      0         1
# 1   2         20       RL         80.0     9600       2      0         1
# 2   3         60       RL         68.0    11250       2      0         2
# 3   4         70       RL         60.0     9550       2      0         2
# 4   5         60       RL         84.0    14260       2      0         2
# 5   6         50       RL         85.0    14115       2      0         2
# 6   7         20       RL         75.0    10084       2      0         1
# 7   8         60       RL          NaN    10382       2      0         2
# 8   9         50       RM         51.0     6120       2      0         1
# 9  10        190       RL         50.0     7420       2      0         1
#
#   LandContour  Utilities    ...     PoolArea  PoolQC Fence MiscFeature  \
# 0         Lvl          4    ...            0       0     0        None
# 1         Lvl          4    ...            0       0     0        None
# 2         Lvl          4    ...            0       0     0        None
# 3         Lvl          4    ...            0       0     0        None
# 4         Lvl          4    ...            0       0     0        None
# 5         Lvl          4    ...            0       0     3        Shed
# 6         Lvl          4    ...            0       0     0        None
# 7         Lvl          4    ...            0       0     0        Shed
# 8         Lvl          4    ...            0       0     0        None
# 9         Lvl          4    ...            0       0     0        None
#
#   MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2   2008        WD         Normal     208500
# 1       0      5   2007        WD         Normal     181500
# 2       0      9   2008        WD         Normal     223500
# 3       0      2   2006        WD        Abnorml     140000
# 4       0     12   2008        WD         Normal     250000
# 5     700     10   2009        WD         Normal     143000
# 6       0      8   2007        WD         Normal     307000
# 7     350     11   2009        WD         Normal     200000
# 8       0      4   2008        WD        Abnorml     129900
# 9       0      1   2008        WD         Normal     118000
#
# [10 rows x 81 columns]

# %% [markdown]
# ## Adding new Boolean features

# %%
# Booleans
train['_Basement'] = train.TotalBsmtSF>0
train['_Garage'] = train.GarageArea>0
train['_Pool'] = train.PoolArea>0
train['_Fence'] = (train.Fence!= 0)
# combine 4 types of porches
train['_Porch'] = (train.OpenPorchSF+train.EnclosedPorch+train['3SsnPorch']+train.ScreenPorch) > 0

#Rob:added
train['_MasVnrArea'] = (train.MasVnrType != 'None')
train['_WoodDeck'] = train.WoodDeckSF > 0
train['_MiscFeature'] = (train.MiscFeature!='None')

# %%
# More Booleans
train['_New'] = train.YearBuilt > 2000 #Rob: what's the justification for using yr 2000 as the cut off?
train['_Remodeled'] = train.YearRemodAdd != train.YearBuilt
train['_NormalSale'] = train.SaleCondition=='Normal'
train['_AfterWW2'] = (train.YearBuilt >= 1946) #Rob:added per Sam's analysis

# %%
new_boolean = ['_Basement', '_Garage', '_Pool', '_Fence', '_Porch','_MasVnrArea','_WoodDeck', '_MiscFeature','_New',
               '_Remodeled', '_NormalSale','_AfterWW2']

# %%
for f in new_boolean:
    train[f]=train[f].astype(np.int64)

# %% [markdown]
# ## Clustering: Categorical

# %%
# (optionally add TSNE / UMAP)

# %%
all_categorical = cat_nominal + cat_ordinal + new_boolean

# %%
print(f'all categorical + boolean features count: {len(all_categorical)}')
# Out:
# all categorical + boolean features count: 58

# %%
chisq_table = np.zeros((len(all_categorical), len(all_categorical)))

for i, f1 in enumerate(all_categorical):
    for j, f2 in enumerate(all_categorical):
        tab = pd.crosstab(train[f1], train[f2])
        chisq_table[i,j] = scipy.stats.chi2_contingency(tab)[1]

sort_order = np.argsort(chisq_table.sum(axis=0))
chisq_table = chisq_table[:,sort_order]
chisq_table = chisq_table[sort_order,:]
heatmap_labels = [all_categorical[i] for i in sort_order]

# %%
plt.figure(figsize=(12,12))
sns.heatmap(chisq_table, cmap="Greens", xticklabels=heatmap_labels, yticklabels=heatmap_labels)

# %% [markdown]
# - The core group of ~10-15 defining characteristics at the top, highly influential (ExterQual, MSSubClass, Neighborhood, New, etc)
# - A few categories at the bottom seem to be randomly spread -> candidates for removal (Utilities, PoolQC, YrSold, MoSold)

# %% [markdown]
# ## ANOVA

# %% [markdown]
# Verify the clustering intuition with ANOVA LogPrice~Category

# %%
# ANOVA requires that the response variables be ~ normal. Log transform the SalePrice.

# %%
train['LogPrice']=np.log(train.SalePrice)

# %%
f,axes = plt.subplots(1, 2, figsize=(10, 4))

sns.distplot(train.SalePrice, ax=axes[0])
sns.distplot(train.LogPrice, ax=axes[1])
# Out:
# /Users/rknatuahene/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# ANOVA F-statistic with its p-value

#Rob: I don't think this test is useful. It's basically checking if the sub-groups within each categorical feature are
#statistically different. we care more about independence of features not of sub-groups within each feature
F_values, p_values = {},{}

for f in all_categorical:
    group_prices = []
    for group in train[f].unique():
        group_prices.append(train[train[f]==group]['LogPrice'].values)

    F_values[f], p_values[f] = scipy.stats.f_oneway(*group_prices)

# %%
F_values = {k:v for k,v in sorted(F_values.items(), key=lambda x: x[1])}
p_values = {k:v for k,v in sorted(p_values.items(), key=lambda x: x[1])}

# %%
p_values
# Out:
# {'Neighborhood': 4.043303832360543e-243,
#  'ExterQual': 6.935425362944559e-195,
#  'BsmtQual': 2.031281939790327e-188,
#  'KitchenQual': 4.441486382628392e-187,
#  'GarageFinish': 4.0574576290308245e-151,
#  'GarageType': 8.427845377348759e-125,
#  'MSSubClass': 5.096022741004154e-115,
#  'FireplaceQu': 6.963457634813553e-115,
#  'Foundation': 1.3506710541411921e-111,
#  '_New': 3.251253283919394e-84,
#  'HeatingQC': 1.6148821620760695e-82,
#  'BsmtFinType1': 4.321403736699806e-78,
#  'MasVnrType': 1.670060794295124e-65,
#  'MSZoning': 1.0213428543580432e-59,
#  'Exterior1st': 1.0531276910218475e-53,
#  '_MasVnrArea': 1.336617663400456e-53,
#  'Exterior2nd': 2.4299379665258745e-49,
#  'GarageCond': 2.508057924124717e-47,
#  'BsmtExposure': 2.590707192162915e-47,
#  '_AfterWW2': 1.6619228183491807e-46,
#  'GarageQual': 6.0684056617209285e-46,
#  'CentralAir': 9.855628007877155e-44,
#  'SaleCondition': 1.6897076360289594e-41,
#  '_Porch': 1.2584483153489537e-37,
#  '_Garage': 8.411473139612348e-37,
#  '_WoodDeck': 3.3912358733396616e-36,
#  'SaleType': 5.497893082953038e-36,
#  'PavedDrive': 1.090995386182895e-31,
#  'HouseStyle': 1.6360765196503422e-30,
#  'Electrical': 4.044950633821188e-30,
#  'LotShape': 7.856968327809616e-29,
#  'BsmtCond': 1.4927541408939521e-27,
#  '_Basement': 1.3701510963874276e-14,
#  'ExterCond': 6.540305132433306e-14,
#  'Fence': 6.560318639536422e-13,
#  'RoofStyle': 1.7057398533064975e-12,
#  'BldgType': 3.4367936403015973e-12,
#  'BsmtFinType2': 5.805631573671444e-12,
#  '_Fence': 9.122430628536669e-12,
#  'Condition1': 1.1734435978022686e-10,
#  'Alley': 1.3581081167013773e-09,
#  'Heating': 2.4843122520789224e-09,
#  'LandContour': 3.086224233553641e-08,
#  'LotConfig': 6.214574667520688e-07,
#  'Functional': 4.250369897366632e-06,
#  '_NormalSale': 9.698218990719762e-05,
#  'RoofMatl': 0.00045042393173255464,
#  '_MiscFeature': 0.0030617650883985157,
#  '_Remodeled': 0.004804645300236131,
#  'MiscFeature': 0.006059927724105702,
#  '_Pool': 0.007599481221588151,
#  'PoolQC': 0.007695550784084371,
#  'Condition2': 0.013820415451446329,
#  'Street': 0.028379306326552542,
#  'LandSlope': 0.3388375097135184,
#  'MoSold': 0.44966156911012456,
#  'YrSold': 0.5656374175357914,
#  'Utilities': 0.6296094276396587}

# %% [markdown]
# Possible candiates to remove with p-value >0.01:
# - 'Condition2'
# - 'Street'
# - 'LandSlope'
# - 'MoSold'
# - 'YrSold'
# - 'Utilities'

# %% [markdown]
# ## Classify and Visualize

# %%
len(all_categorical)
# Out:
# 58

# %%
cat_elements = [
 'RoofStyle',
 'RoofMatl',
 'Exterior1st',
 'Exterior2nd',
 'MasVnrType',
 'Heating',
 'GarageType',
 'MiscFeature',  # mainly shed
 
 'Foundation',
 'Electrical',
 'Fence',
 'Utilities',
 
 'ExterQual',
 'ExterCond',
 'BsmtQual',
 'BsmtCond',
 'BsmtExposure',
 'BsmtFinType1',
 'BsmtFinType2',
 'HeatingQC',
 'CentralAir',
 'KitchenQual',

 'FireplaceQu',
 'GarageFinish',
 'GarageQual',
 'GarageCond',
 'PoolQC',
 '_Basement',
 '_Garage',
 '_Pool',
 '_Fence',
 '_Porch',
 '_MasVnrArea',
 '_WoodDeck',
 '_MiscFeature',
 '_AfterWW2'
]

# %%
len(cat_elements) #Rob:changed variable name from elements to cat_elements
# Out:
# 36

# %%
# [x for x in all_categorical if x not in elements] ,'_New',

# %%
cat_location = [
'MSZoning',
'Neighborhood',
'Condition1',
'Condition2',
]
                
cat_sale = [            
'SaleType',
'SaleCondition',
'_NormalSale',
'MoSold',
'YrSold',
]
    
cat_type = [
'MSSubClass',
'BldgType',
'HouseStyle',
'Functional',
'_Remodeled',
'_New',
]

cat_land = [    
'LotShape',
'LandSlope',
'LandContour',
'LotConfig',
'Street',
'Alley',
'PavedDrive',
]

# %%
# verify completeness
assert set(all_categorical)==set(cat_elements+cat_location+cat_sale+cat_type+cat_land)
assert len(all_categorical)==len(cat_elements+cat_location+cat_sale+cat_type+cat_land)

# %%
def plot_counts(cat_group, col_wrap=4):
    f = pd.melt(train, value_vars=cat_group)
    g = sns.FacetGrid(f, col='variable', col_wrap=col_wrap, sharex=False, sharey=False)
    g = g.map(sns.countplot, 'value')
    [plt.setp(ax.get_xticklabels(), rotation=90) for ax in g.axes.flat]
    g.fig.tight_layout()
    plt.show()

# %%
#Rob: Proceeding histograms do not really tell us much. consider removing from the final notebook

# %%
plot_counts(cat_elements)
# Out:
# /Users/rknatuahene/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:715: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
plot_counts(cat_location)
# Out:
# /Users/rknatuahene/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:715: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
plot_counts(cat_sale)
# Out:
# /Users/rknatuahene/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:715: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
plot_counts(cat_type)
# Out:
# /Users/rknatuahene/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:715: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
plot_counts(cat_land)
# Out:
# /Users/rknatuahene/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:715: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# ## Influential features

# %%
#Select least p-value features on the F-test. Visualize Boxplots (Price or LogPrice?)

# %%
cat_influential = [
# from cat_location
'Neighborhood',
'MSZoning',
# from the cat_sale
'SaleCondition',
'SaleType',    
# from cat_type
'MSSubClass',
'_New',
# zero from the cat_land
# from cat_elements    

'KitchenQual',
'FireplaceQu',
'Foundation',
'HeatingQC',
'CentralAir',    
'MasVnrType',
'_Porch',  
    
'Exterior1st',
'Exterior2nd',
'ExterQual',   
    
'GarageFinish',
'GarageType',
'GarageQual',    
'GarageCond',
'_Garage',    
'Fence',   
'BsmtQual',
'BsmtExposure',    
'BsmtFinType1'    
]
print(f'Inflential features:  {len(cat_influential)}')
# Out:
# Inflential features:  25

# %%
# plt.subplots(nrows, ncols, figsize=(width, height))
#Rob: nice graphs showing encoded ordinal values displaying order as expected. 
#Rob: code didn't run properly as is. what's the variable n? I changed to nc to work
nc =3
nr  = 1+math.ceil(len(cat_influential)//nc)
f,axes = plt.subplots(nr, nc, figsize=(nc*5, nr*5))
f.subplots_adjust(hspace=.5, wspace=.3,)

counter = 0
for f in cat_influential:
    ax = sns.boxplot(f, 'SalePrice', data=train, ax = axes[counter//nc][counter%nc])
    ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
    counter+=1

# %% [markdown]
# ## Numerical features
# split numerical features into discrete and continous for ease of visual analysis

# %%
num_continous =[
'LotFrontage',
'LotArea',
'MasVnrArea',
'BsmtFinSF1',
'BsmtFinSF2',
'BsmtUnfSF',
'TotalBsmtSF',
'1stFlrSF',
'2ndFlrSF',
'LowQualFinSF',
'GrLivArea',
'GarageArea',
'WoodDeckSF',
'OpenPorchSF',
'EnclosedPorch',
'3SsnPorch',
'ScreenPorch',
'PoolArea',
'MiscVal'
]

# %%
num_continous
# Out:
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal']

# %%
train[num_continous].describe().T
# Out:
#                 count          mean          std     min      25%     50%  \
# LotFrontage    1201.0     70.049958    24.284752    21.0    59.00    69.0
# LotArea        1460.0  10516.828082  9981.264932  1300.0  7553.50  9478.5
# MasVnrArea     1452.0    103.685262   181.066207     0.0     0.00     0.0
# BsmtFinSF1     1460.0    443.639726   456.098091     0.0     0.00   383.5
# BsmtFinSF2     1460.0     46.549315   161.319273     0.0     0.00     0.0
# BsmtUnfSF      1460.0    567.240411   441.866955     0.0   223.00   477.5
# TotalBsmtSF    1460.0   1057.429452   438.705324     0.0   795.75   991.5
# 1stFlrSF       1460.0   1162.626712   386.587738   334.0   882.00  1087.0
# 2ndFlrSF       1460.0    346.992466   436.528436     0.0     0.00     0.0
# LowQualFinSF   1460.0      5.844521    48.623081     0.0     0.00     0.0
# GrLivArea      1460.0   1515.463699   525.480383   334.0  1129.50  1464.0
# GarageArea     1460.0    472.980137   213.804841     0.0   334.50   480.0
# WoodDeckSF     1460.0     94.244521   125.338794     0.0     0.00     0.0
# OpenPorchSF    1460.0     46.660274    66.256028     0.0     0.00    25.0
# EnclosedPorch  1460.0     21.954110    61.119149     0.0     0.00     0.0
# 3SsnPorch      1460.0      3.409589    29.317331     0.0     0.00     0.0
# ScreenPorch    1460.0     15.060959    55.757415     0.0     0.00     0.0
# PoolArea       1460.0      2.758904    40.177307     0.0     0.00     0.0
# MiscVal        1460.0     43.489041   496.123024     0.0     0.00     0.0
#
#                     75%       max
# LotFrontage       80.00     313.0
# LotArea        11601.50  215245.0
# MasVnrArea       166.00    1600.0
# BsmtFinSF1       712.25    5644.0
# BsmtFinSF2         0.00    1474.0
# BsmtUnfSF        808.00    2336.0
# TotalBsmtSF     1298.25    6110.0
# 1stFlrSF        1391.25    4692.0
# 2ndFlrSF         728.00    2065.0
# LowQualFinSF       0.00     572.0
# GrLivArea       1776.75    5642.0
# GarageArea       576.00    1418.0
# WoodDeckSF       168.00     857.0
# OpenPorchSF       68.00     547.0
# EnclosedPorch      0.00     552.0
# 3SsnPorch          0.00     508.0
# ScreenPorch        0.00     480.0
# PoolArea           0.00     738.0
# MiscVal            0.00   15500.0

# %% [markdown]
# ### Check for missingness and impute

# %%
train[num_continous].isnull().sum(axis=0)
# Out:
# LotFrontage      259
# LotArea            0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# dtype: int64

# %%
#missingness as a percentage of total rows
train[num_continous].isnull().sum(axis=0)/train.shape[0]
# Out:
# LotFrontage      0.177397
# LotArea          0.000000
# MasVnrArea       0.005479
# BsmtFinSF1       0.000000
# BsmtFinSF2       0.000000
# BsmtUnfSF        0.000000
# TotalBsmtSF      0.000000
# 1stFlrSF         0.000000
# 2ndFlrSF         0.000000
# LowQualFinSF     0.000000
# GrLivArea        0.000000
# GarageArea       0.000000
# WoodDeckSF       0.000000
# OpenPorchSF      0.000000
# EnclosedPorch    0.000000
# 3SsnPorch        0.000000
# ScreenPorch      0.000000
# PoolArea         0.000000
# MiscVal          0.000000
# dtype: float64

# %% [markdown]
# We need to impute LotFrontage and MasVnrArea missing values.

# %%
#let the data speak for itself. use KNN to impute with n = sqrt(nrow(train))
imputer = KNNImputer(n_neighbors= round(np.sqrt(train.shape[0])))
train['LotFrontage'] = imputer.fit_transform(train['LotFrontage'][:,np.newaxis])
train['MasVnrArea'] = imputer.fit_transform(train['MasVnrArea'][:,np.newaxis])

# %%
#no more missingness
train[num_continous].isnull().sum(axis=0)
# Out:
# LotFrontage      0
# LotArea          0
# MasVnrArea       0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# dtype: int64

# %% [markdown]
# ## Numerical features: transformations

# %%
#density plots of original numerica features
f = pd.melt(train[num_continous][train[num_continous]>0], value_vars=sorted(num_continous))
g = sns.FacetGrid(f, col='variable', col_wrap=3, sharex=False, sharey=False)
g = g.map(sns.distplot, 'value')
# Out:
# /Users/rknatuahene/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# pretty much every numerical feature exhibits right skewness - these are good candidates for log transformation

# %%
num_continous
# Out:
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal']

# %%
##transform all numerical values
train_transformed = train[num_continous].copy()
for f in num_continous:
    train_transformed.loc[:,f] = np.log1p(train[f])

# %%
##plot before and after charts
for f in num_continous:
    fig,axes = plt.subplots(1, 2, figsize=(15, 4))
    g = sns.distplot(train[f][train[f] != 0], ax=axes[0])
    g.set(xlabel =f"{f} before log transform")
    g = sns.distplot(train_transformed[f][train_transformed[f] != 0], ax=axes[1])
    g.set(xlabel =f"{f} after log transform")

# %% [markdown]
# numerical features are closer to the normal curve post transformation

# %%
train_transformed.columns
# Out:
# Index(['LotFrontage', 'LotArea', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch',
#        '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal'],
#       dtype='object')

# %%
##scatter plot of saleprice vs the log transformed predictors
#num_continous = num_continous.remove('LogPrice')

for f in num_continous:
    fig,axes = plt.subplots(1, 1, figsize=(10, 4))
    g = sns.regplot(train_transformed[f][train_transformed[f]!=0], train['LogPrice'][train_transformed[f]!=0])

# %% [markdown]
# BsmtFinSF1 might fit better with quadratic.
# Strongest linear relationships:
#     LotFrontage, LotArea, MasVnrArea,TotalBsmtSF, 1stFlrSF, 2ndFlrSF, GrLivArea, GarageArea, WoodDeckSF

# %%
#another way is to look at their correlation to LogPrice
train_transformed['LogPrice'] = train['LogPrice']
corMatrix = train_transformed.corr()
plt.subplots(figsize=(12,9))
sns.heatmap(corMatrix, cmap="Blues")

# %%
##hone in on top k most correlated
k = 10 #number of variables for heatmap
cols = corMatrix.nlargest(k, 'LogPrice')['LogPrice'].index
cm = np.corrcoef(train_transformed[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cmap="Blues", cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
#another view of correlation to saleprice
corr = corMatrix.sort_values('LogPrice', ascending=False)
plt.figure(figsize=(8,10))
sns.barplot( corr.LogPrice[1:], corr.index[1:], orient='h')
plt.show()

# %% [markdown]
# All 3 correlation plots support the conclusions from the scatter plots.

# %% [markdown]
# ## Numerical features : standardization

# %%
#good idea to standardize numerical predictors to put them all on similar scales - helps to get sane regression
#coefficients with penalization.
for f in num_continous:
    train_transformed[f] = StandardScaler().fit_transform(train_transformed[f][:,np.newaxis])

# %% [markdown]
# ## Feature Generation

# %%
##adding some numerical features that are usually looked at together

train_transformed['TotalSF'] = train_transformed.TotalBsmtSF + train_transformed.GrLivArea
train_transformed['TotalFloorSF'] = train_transformed['1stFlrSF'] + train_transformed['2ndFlrSF']
train_transformed['TotalPorchSF'] = train_transformed.OpenPorchSF + train_transformed.EnclosedPorch + \
    train_transformed['3SsnPorch'] + train_transformed.ScreenPorch

# %%
num_continous += ['TotalSF','TotalFloorSF','TotalPorchSF']

# %%
num_continous= list(set(num_continous))
num_continous
# Out:
# ['LowQualFinSF',
#  '3SsnPorch',
#  'GrLivArea',
#  'OpenPorchSF',
#  'BsmtFinSF2',
#  'BsmtFinSF1',
#  'TotalBsmtSF',
#  'PoolArea',
#  'LotArea',
#  'WoodDeckSF',
#  'GarageArea',
#  'TotalFloorSF',
#  '1stFlrSF',
#  'TotalSF',
#  'EnclosedPorch',
#  'MiscVal',
#  'TotalPorchSF',
#  'LotFrontage',
#  'BsmtUnfSF',
#  'ScreenPorch',
#  '2ndFlrSF',
#  'MasVnrArea']

# %% [markdown]
# ## Merge transformed features back to master data frame

# %%
for f in num_continous:
    train[f] = train_transformed[f]

# %% [markdown]
# ## Write processed training data to CSV

# %%
train.shape
# Out:
# (1460, 97)

# %%
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice', '_Basement', '_Garage', '_Pool', '_Fence',
#        '_Porch', '_MasVnrArea', '_WoodDeck', '_MiscFeature', '_New',
#        '_Remodeled', '_NormalSale', '_AfterWW2', 'LogPrice', 'TotalFloorSF',
#        'TotalSF', 'TotalPorchSF'],
#       dtype='object')

# %%
train.to_csv('data/processed_train.csv', index=False)
